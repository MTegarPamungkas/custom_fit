# %% [markdown]
# ### 0. Architecture Deep Learning

# %% [markdown]
# ![](https://d3i71xaburhd42.cloudfront.net/b8eb0dd0f698d4a51488532931912851b36665f9/3-Figure2-1.png)

# %% [markdown]
# ### 1. Preview Result Model

# %% [markdown]
# #### 1.1. In-Out Tucking

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# #### 1.2. Virtual Try On

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ![](data:image/png;base64,...)
